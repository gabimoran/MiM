# %%
# !python --version
# Out:
# Python 3.10.15

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import torch
print("Versión de PyTorch:", torch.__version__)
print("CUDA disponible:", torch.cuda.is_available())
print("Versión de CUDA:", torch.version.cuda)
print("Dispositivos disponibles:", torch.cuda.device_count())
print("Nombre de la GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No hay GPU disponible")
# Out:
# Versión de PyTorch: 2.5.0
# CUDA disponible: True
# Versión de CUDA: 11.8
# Dispositivos disponibles: 1
# Nombre de la GPU: NVIDIA GeForce RTX 4090 Laptop GPU

# %%
# !nvidia-smi
# Out:
# Sat Oct 26 21:01:20 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.03                 Driver Version: 566.03         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4090 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   53C    P8              8W /   97W |     286MiB /  16376MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A     17116    C+G   ...pIntegrations\Grammarly.Desktop.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torchvision

print(torchvision.__version__)
# Out:
# 0.20.0

# %%
x = torch.tensor([0.5, 1.5])

# %%
print(x.device)
# Out:
# cpu

# %%
device = torch.device("cuda:0")

# %%
x = x.to(device)

# %%
print(x.device)
# Out:
# cuda:0

# %%
# definimos un objeto device para la cpu
device = torch.device("cpu")
# movemos el tensor
x = x.to(device)
print(x)
print(x.device)
# Out:
# tensor([0.5000, 1.5000])
# cpu
